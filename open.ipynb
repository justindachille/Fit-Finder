# %%
import pandas as pd

obj = pd.read_pickle(r'./job_listings.pkl')

# %%
obj
# Out:
# [{'title': 'Endur Developer - Wipro Limited - London',
#   'company': 'Wipro Limited',
#   'location': 'London',
#   'published': 'Tue, 28 May 2024 18:19:15 GMT',
#   'salary': None,
#   'summary': 'London, United Kingdom Tech Hiring 3077852 Job Description Wipro’s dynamic approach to people, process, and technology has led them to be an industry leader…<br />From Wipro Limited - Tue, 28 May 2024 18:19:15 GMT - View all <a href="https://uk.indeed.com/jobs?l=London">London jobs</a>',
#   'link': 'https://uk.indeed.com/viewjob?t=Endur+Developer&c=Wipro&l=London&jk=676c6b4b126485fe&rtk=1hv0jp11gikco800&from=rss',
# ...
